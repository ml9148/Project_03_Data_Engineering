# %%
# Import dependencies
import pandas as pd

# %%
# Load in the original data
df0 = pd.read_csv("Resources/Detail_listings.csv")
df0.head()
# Out:
# C:\Users\aed3h\AppData\Local\Temp\ipykernel_20684\1708966191.py:2: DtypeWarning: Columns (87) have mixed types. Specify dtype option on import or set low_memory=False.
#   df0 = pd.read_csv("Resources/Detail_listings.csv")
#          id                            listing_url       scrape_id  \
# 0  16228948  https://www.airbnb.com/rooms/16228948  20170502172350
# 1   8909380   https://www.airbnb.com/rooms/8909380  20170502172350
# 2  14078522  https://www.airbnb.com/rooms/14078522  20170502172350
# 3  13006928  https://www.airbnb.com/rooms/13006928  20170502172350
# 4   7898757   https://www.airbnb.com/rooms/7898757  20170502172350
#
#   last_scraped                                             name  \
# 0   2017-05-03  Robert Ranch in Los Angeles for filming/wedding
# 1   2017-05-03                   Nice quiet private ranch house
# 2   2017-05-03               Room w/private bath on Small Ranch
# 3   2017-05-03                           Miller Ranch Bunkhouse
# ...

# %%
# Drop columns not relevant to our database
df = df0.drop(columns=['listing_url','scrape_id','last_scraped','experiences_offered','thumbnail_url','medium_url','picture_url','xl_picture_url','host_url',
'host_acceptance_rate','host_thumbnail_url','host_picture_url','neighbourhood_group_cleansed','calendar_updated','has_availability','availability_30',
'availability_60','availability_90','availability_365','calendar_last_scraped','requires_license','license','jurisdiction_names'])
df.head()
# Out:
#          id                                             name  \
# 0  16228948  Robert Ranch in Los Angeles for filming/wedding
# 1   8909380                   Nice quiet private ranch house
# 2  14078522               Room w/private bath on Small Ranch
# 3  13006928                           Miller Ranch Bunkhouse
# 4   7898757                        Studio with full bathroom
#
#                                              summary  \
# 0  Stunning Ranch Estate situated on 20 acres and...
# 1                                                NaN
# 2  My place is close to Six Flags Magic Mountain ...
# 3  Our place is close to great views, equestrian ...
# 4  Fully furnished studio only a 10 min drive fro...
#
#                                                space  \
# 0                                                NaN
# 1  Very private and quite . Hiking horse riding a...
# 2               Room with queen bed and private bath
# 3  Please know that we live on a dirt road but it...
# ...

# %%
# Check primary key columns / NOT NULL col for null values
# listing id, host id, price 
print(df[df["id"].isna()])
print(df[df["host_id"].isna()])
print(df[df["price"].isna()])
# Out:
# Empty DataFrame
# ...

# %%
# Take a random sample to use for project
sample_df = df.sample(n=10000, random_state=42, ignore_index=True)
sample_df.head()
# Out:
#          id                                    name  \
# 0  15461810    Cozy Private Room with parking (12B)
# 1  13416156            2 bedrooms and 1.5 bathrooms
# 2   9136734  10 min walk to Abbot Kinney in Venice!
# 3   3378135          Large room in Culver/Mar Vista
# 4   4403665     Silver Lake, Large 1BD with views 7
#
#                                              summary  \
# 0  Very small room with twin bed. This room is a ...
# 1  Our comfortable,  quiet rooms, located on the ...
# 2  Beautiful, newly remodeled 3BR 2BA apartment i...
# 3  The perfect place for travelers in the best ar...
# 4  Stay 31 days or more and pay no taxes. Large b...
#
#                                                space  \
# 0  This very small room is located in a dorm-styl...
# 1  This a single family house, 4 Bedrooms and 2.5...
# 2  Comfortable space that feels like home, our pl...
# 3  This large, private room is perfect for any tr...
# 4  Unlike many other guest rentals you will find ...
#
# ...

# %%
# Check datatypes
for column in sample_df.columns:
    print(f"{column}: {sample_df[column].dtype}")
# Out:
# id: int64
# name: object
# summary: object
# space: object
# description: object
# neighborhood_overview: object
# notes: object
# transit: object
# access: object
# interaction: object
# house_rules: object
# host_id: int64
# host_name: object
# host_since: object
# host_location: object
# host_about: object
# host_response_time: object
# host_response_rate: object
# host_is_superhost: object
# host_neighbourhood: object
# host_listings_count: float64
# host_total_listings_count: float64
# host_verifications: object
# host_has_profile_pic: object
# host_identity_verified: object
# street: object
# neighbourhood: object
# neighbourhood_cleansed: object
# city: object
# state: object
# zipcode: object
# market: object
# smart_location: object
# country_code: object
# country: object
# latitude: float64
# longitude: float64
# is_location_exact: object
# property_type: object
# room_type: object
# accommodates: int64
# bathrooms: float64
# bedrooms: float64
# beds: float64
# ...

# %%
# Convert datatypes


sample_df['host_name'] = sample_df['host_name'].astype('string')
sample_df['host_since'] = pd.to_datetime(sample_df['host_since'])
sample_df['host_location'] = sample_df['host_location'].astype('string')
sample_df['host_about'] = sample_df['host_about'].astype('string')
sample_df['host_response_time'] = sample_df['host_response_time'].astype('string')
sample_df['host_response_rate'] = sample_df['host_response_rate'].astype('string')
sample_df['host_is_superhost'] = sample_df['host_is_superhost'].astype('string')
sample_df['host_neighbourhood'] = sample_df['host_neighbourhood'].astype('string')
sample_df['host_listings_count'] = sample_df['host_listings_count'].astype('Int64')
sample_df['host_total_listings_count'] = sample_df['host_total_listings_count'].astype('Int64')
sample_df['host_verifications'] = sample_df['host_verifications'].astype('string')
sample_df['host_has_profile_pic'] = sample_df['host_has_profile_pic'].astype('string')
sample_df['host_identity_verified'] = sample_df['host_identity_verified'].astype('string')

# %%
# Confirm data type changes
for column in sample_df.columns:
    print(f"{column}: {sample_df[column].dtype}")
# Out:
# id: int64
# name: object
# summary: object
# space: object
# description: object
# neighborhood_overview: object
# notes: object
# transit: object
# access: object
# interaction: object
# house_rules: object
# host_id: int64
# host_name: string
# host_since: datetime64[ns]
# host_location: string
# host_about: string
# host_response_time: string
# host_response_rate: string
# host_is_superhost: string
# host_neighbourhood: string
# host_listings_count: Int64
# host_total_listings_count: Int64
# host_verifications: string
# host_has_profile_pic: string
# host_identity_verified: string
# street: object
# neighbourhood: object
# neighbourhood_cleansed: object
# city: object
# state: object
# zipcode: object
# market: object
# smart_location: object
# country_code: object
# country: object
# latitude: float64
# longitude: float64
# is_location_exact: object
# property_type: object
# room_type: object
# accommodates: int64
# bathrooms: float64
# bedrooms: float64
# beds: float64
# ...

# %%
# Perform any further changes to data types / columns

# Host response rate column: 
# remove the percent symbol, trailing characters and whitespaces, and convert to integer
sample_df['host_response_rate'] = (sample_df['host_response_rate'].str.strip('%').str.strip('.0').str.strip()
                                   .replace('', pd.NA).astype(float).astype('Int64'))

# Superhost column:
# Convert t and f to boolean values and datatype
sample_df['host_is_superhost'] = sample_df['host_is_superhost'].fillna('f').map({'t': True, 'f': False})

# Host profile pic column:
sample_df['host_has_profile_pic'] = sample_df['host_has_profile_pic'].fillna('f').map({'t': True, 'f': False})

# %%
# Confirm further data type changes
print(f"host_response_rate: {sample_df['host_response_rate'].dtype}")
print(f"host_is_superhost: {sample_df['host_is_superhost'].dtype}")
print(f"host_has_profile_pic: {sample_df['host_has_profile_pic'].dtype}")
# Out:
# host_response_rate: Int64
# host_is_superhost: bool
# host_has_profile_pic: bool

# %%
sample_df.to_csv("Resources/Listings_Cleaned_Sample.csv")
