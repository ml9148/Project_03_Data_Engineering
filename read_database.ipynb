# %%
# Import dependencies
from sqlalchemy import create_engine
import pandas as pd
from config import username, password

# %%
# Create engine connecting to database path
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/project_3_g1')

# %%
# Define queries
query_hosts = "SELECT * FROM host"
query_pvr = "SELECT * FROM pricing_vs_reviews"
query_reviews = "SELECT * FROM comprehensive_reviews"
query_listing = "SELECT * FROM final_listing_cleaned"
query_sentiment = "SELECT * FROM sentiment"
query_location = "SELECT * from listing_location_details"
query_housing = "SELECT * from housing_details_data_cleaned"

# %%
### Read tables into DataFrames:


# Hosts table to DataFrame
df_hosts = pd.read_sql(query_hosts, engine)
df_hosts.head()
# Out:
#    host_id host_name  host_since                           host_location  \
# 0      767   Melissa  2008-07-11      Burbank, California, United States
# 1     3415   Nataraj  2008-10-02  Los Angeles, California, United States
# 2     3685       Jen  2008-10-16                           United States
# 3     6829   Barrett  2009-01-16  Los Angeles, California, United States
# 4     9171     Sanni  2009-03-05  Los Angeles, California, United States
#
#   host_response_time  host_response_rate  host_is_superhost  \
# 0               None                 NaN              False
# 1       within a day                70.0              False
# 2       within a day                90.0               True
# 3     within an hour               100.0              False
# 4     within an hour               100.0               True
#
#   host_neighbourhood  host_total_listings_count  host_listings_in_sample  \
# 0            Burbank                        1.0                      1.0
# 1      Laurel Canyon                        6.0                      1.0
# 2        Studio City                        4.0                      2.0
# 3           Mid-City                        5.0                      2.0
# 4            Del Rey                        7.0                      2.0
#
#                                   host_verifications  host_has_profile_pic  \
# 0      ['email', 'phone', 'reviews', 'jumio', 'kba']                  True
# 1             ['email', 'phone', 'reviews', 'jumio']                  True
# 2  ['email', 'phone', 'facebook', 'reviews', 'kba...                  True
# 3             ['email', 'phone', 'reviews', 'jumio']                  True
# 4          ['email', 'phone', 'facebook', 'reviews']                  True
#
#    host_identity_verified
# 0                    True
# 1                    True
# 2                    True
# 3                    True
# 4                   False

# %%
# Locations table to DataFrame
df_listing_location_details = pd.read_sql(query_listing, engine)
df_listing_location_details.head()
# Out:
#          id   host_id    price       affordability
# 0  15461810   9464908   $25.00         Cheap $0-49
# 1  13416156  48449293  $115.00  affordable $51-200
# 2   9136734  45839570  $135.00  affordable $51-200
# 3   3378135    171168   $69.00  affordable $51-200
# 4   4403665   8258320  $130.00  affordable $51-200

# %%
# Reviews table to DataFrame
df_reviews = pd.read_sql(query_reviews, engine)
df_reviews.head()
# Out:
#     Host ID  Number of Reviews First Review Last Review  Overall Rating  \
# 0   9464908                  1   2016-11-14  2016-11-14           100.0
# 1  48449293                  6   2016-08-01  2017-02-13           100.0
# 2  45839570                  1   2017-01-01  2017-01-01            80.0
# 3    171168                 14   2014-07-20  2016-08-21            91.0
# 4   8258320                 22   2014-11-17  2017-02-05            97.0
#
#   Review Score  Accuracy  Cleanliness  Check-In  Communication  Location  \
# 0    Very High      10.0          6.0       NaN           10.0       NaN
# 1    Very High      10.0         10.0      10.0           10.0      10.0
# 2         High      10.0          8.0      10.0           10.0      10.0
# 3    Very High       9.0          8.0      10.0           10.0      10.0
# 4    Very High      10.0         10.0      10.0           10.0       9.0
#
#    Value Reviews per Month   Category Average
# 0    NaN              0.18  8.666666666666666
# 1   10.0              0.65               10.0
# 2   10.0              0.24  9.666666666666666
# 3    9.0              0.41  9.333333333333334
# 4    9.0              0.73  9.666666666666666

# %%
# Locations table to DataFrame
df_housing = pd.read_sql(query_housing, engine)
df_housing.head()
# Out:
#          id   host_id neighbourhood_cleansed property_type        room_type  \
# 0  15461810   9464908              Inglewood          Dorm     Private room
# 1  13416156  48449293        Rowland Heights         House     Private room
# 2   9136734  45839570                 Venice     Apartment  Entire home/apt
# 3   3378135    171168              Mar Vista     Apartment     Private room
# 4   4403665   8258320            Silver Lake     Apartment  Entire home/apt
#
#    accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0             1        1.0       1.0   1.0  Real Bed
# 1             4        1.5       2.0   2.0  Real Bed
# 2             6        2.0       3.0   3.0  Real Bed
# 3             1        1.0       1.0   1.0     Futon
# 4             2        1.0       1.0   1.0  Real Bed
#
#                                            amenities
# 0  {"Wireless Internet",Kitchen,"Free parking on ...
# 1  {TV,"Wireless Internet","Air conditioning",Kit...
# 2  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 3  {TV,Internet,"Wireless Internet",Kitchen,Heati...
# 4  {TV,"Cable TV",Internet,"Wireless Internet","A...

# %%
# Price vs. Reviews table to DataFrame
df_price_reviews = pd.read_sql(query_pvr, engine)
df_price_reviews.head()
# Out:
#     price  avg_review_per_price  number_of_reviews_sum affordability
# 0  $10.00                   NaN                      0   Cheap $0-49
# 1  $12.00                   NaN                      0   Cheap $0-49
# 2  $15.00              9.250000                    272   Cheap $0-49
# 3  $16.00              8.666667                     21   Cheap $0-49
# 4  $17.00             10.000000                     13   Cheap $0-49

# %%
df_location = pd.read_sql(query_location, engine)
df_location.head()
# Out:
#    listing_id        country country_code             city zipcode  \
# 0    15461810  United States           US        Inglewood   90302
# 1    13416156  United States           US  Rowland Heights   91748
# 2     9136734  United States           US      Los Angeles   90291
# 3     3378135  United States           US      Los Angeles   90066
# 4     4403665  United States           US      Los Angeles   90039
#
#       neighborhood   latitude   longitude       market is_location_exact  \
# 0        Inglewood  33.969759 -118.349800  Los Angeles                 t
# 1  Rowland Heights  33.975104 -117.918121  Los Angeles                 f
# 2           Venice  33.994006 -118.449265  Los Angeles                 t
# 3        Mar Vista  34.002392 -118.427749  Los Angeles                 t
# 4      Silver Lake  34.096575 -118.257904  Los Angeles                 t
#
#   property_type                                    name  \
# 0          Dorm    Cozy Private Room with parking (12B)
# 1         House            2 bedrooms and 1.5 bathrooms
# 2     Apartment  10 min walk to Abbot Kinney in Venice!
# 3     Apartment          Large room in Culver/Mar Vista
# 4     Apartment     Silver Lake, Large 1BD with views 7
#
#                                              summary  \
# 0  Very small room with twin bed. This room is a ...
# 1  Our comfortable,  quiet rooms, located on the ...
# 2  Beautiful, newly remodeled 3BR 2BA apartment i...
# 3  The perfect place for travelers in the best ar...
# 4  Stay 31 days or more and pay no taxes. Large b...
#
#                                neighborhood_overview   host_id
# 0  This is a lower-middle class neighborhood. It ...   9464908
# 1                                       Super quiet!  48449293
# 2                                               None  45839570
# 3  Simply put, I love Mar Vista! I am just 3 mile...    171168
# 4  There are views of the surrounding mountains a...   8258320

# %%
df_listing = pd.read_sql(query_listing, engine)
df_listing.head()
# Out:
#          id   host_id    price       affordability
# 0  15461810   9464908   $25.00         Cheap $0-49
# 1  13416156  48449293  $115.00  affordable $51-200
# 2   9136734  45839570  $135.00  affordable $51-200
# 3   3378135    171168   $69.00  affordable $51-200
# 4   4403665   8258320  $130.00  affordable $51-200
